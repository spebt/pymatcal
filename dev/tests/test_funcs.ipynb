# %%
import torch

# %%
length = 7
index = torch.stack([torch.arange(length).repeat_interleave(4), torch.arange(4).repeat(length)], dim=1)

print(index.shape)
print(index)
# Out:
# torch.Size([28, 2])
# tensor([[0, 0],
#         [0, 1],
#         [0, 2],
#         [0, 3],
#         [1, 0],
#         [1, 1],
#         [1, 2],
#         [1, 3],
#         [2, 0],
#         [2, 1],
#         [2, 2],
#         [2, 3],
#         [3, 0],
#         [3, 1],
#         [3, 2],
#         [3, 3],
#         [4, 0],
#         [4, 1],
#         [4, 2],
#         [4, 3],
#         [5, 0],
#         [5, 1],
#         [5, 2],
#         [5, 3],
#         [6, 0],
#         [6, 1],
#         [6, 2],
#         [6, 3]])
