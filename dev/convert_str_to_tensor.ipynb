# %%
import torch
import pandas as pd

# %%
df = pd.read_csv("data_no_for_loop.csv")

# %%
data = torch.tensor(list(map(int,df["indices"][0][1:-1].split(", "))))
print(data)
# Out:
# tensor([ 0,  1,  2,  3,  4,  5,  6, 22, 23, 72])

# %%
data = torch.tensor(list(map(int, df["indices"][:, 1:-1].split(", "))))
print(data)

# %%
# Out:
# [0
#  1
#  2
#  3
#  4
#  5
#  6
#  22
#  23
#  72]
